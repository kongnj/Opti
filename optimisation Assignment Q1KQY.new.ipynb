# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (center grid)
position = [grid_size // 2, grid_size // 2]

# Define the number of seconds in the simulation (1 hour)
num_seconds = 3600

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1])
# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (1 Hour, Starting at Center)')
plt.show()

#Print the ratio of visit time
print(f'Number of Visit time for 1 Hour starting at Center:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Average Visit time for 1 Hour starting at Center:Central=2692.0, Side=856.0, Corner=52.0

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (center grid)
position = [grid_size // 2, grid_size // 2]

# Define the number of seconds in the simulation (8 hour)
num_seconds = 28800

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1]) 
# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (8 Hour, Starting at Center)')
plt.show()

#Print the ratio of visit time
print(f'Number of Visit time for 8 Hour starting at Center:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Number of Visit time for 8 Hour starting at Center:Central=20875.0, Side=7383.0, Corner=542.0

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (center grid)
position = [grid_size // 2, grid_size // 2]

# Define the number of seconds in the simulation (1 day)
num_seconds = 86400

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1]) 
# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (1 Day, Starting at Center)')
plt.show()

#Print the ratio of visit time
print(f'Number of Visit time for 1 Day starting at Center:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Number of Visit time for 1 Day starting at Center:Central=63888.0, Side=21030.0, Corner=1482.0

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (Upper Right)
position = [0, -1]

# Define the number of seconds in the simulation (1 hour)
num_seconds = 3600

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1]) 

# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (1 Hour, Starting at Upper-right)')
plt.show()
print(f'Number of Visit time for 1 Hour starting at Upper-right:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Number of Visit time for 1 Hour starting at Upper-right:Central=2553.0, Side=973.0, Corner=74.0

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (Upper Right)
position = [0, -1]

# Define the number of seconds in the simulation (8 hour)
num_seconds = 28800

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1]) 
# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (8 Hour, Starting at Upper-right)')
plt.show()
print(f'Number of Visit time for 8 Hour starting at Upper-right:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Number of Visit time for 8 Hour starting at Upper-right:Central=20984.0, Side=7220.0, Corner=596.0

# %%
# Initialize the grid and visit counts
grid_size = 11
visit_counts = np.zeros((grid_size, grid_size))

# Define the starting position (Upper Right)
position = [0, -1]

# Define the number of seconds in the simulation (1 Day)
num_seconds = 86400

# Run the simulation
for _ in range(num_seconds):
    # Update visit counts
    visit_counts[position[0], position[1]] += 1
    
    # Determine the next move
    moves = []
    if position[0] > 0:
        moves.append('up')
    if position[0] < grid_size - 1:
        moves.append('down')
    if position[1] > 0:
        moves.append('left')
    if position[1] < grid_size - 1:
        moves.append('right')
    move = np.random.choice(moves)
    
    # Update position
    if move == 'up':
        position[0] -= 1
    elif move == 'down':
        position[0] += 1
    elif move == 'left':
        position[1] -= 1
    elif move == 'right':
        position[1] += 1
        
central_visit = np.sum(visit_counts[1:-1, 1:-1])
side_visit = (np.sum(visit_counts[0, 1:-1]) +
                      np.sum(visit_counts[-1, 1:-1]) +
                      np.sum(visit_counts[1:-1, 0]) +
                      np.sum(visit_counts[1:-1, -1])) 
corner_visit = (visit_counts[0, 0] +
                        visit_counts[0, -1] +
                        visit_counts[-1, 0] +
                        visit_counts[-1, -1]) 
# Plot the visit counts
plt.imshow(visit_counts, cmap='Blues', interpolation='nearest')
plt.colorbar(label='Visit Count')
plt.title('Robotic Vacuum Visit Counts (1 Day, Starting at Upper-right)')
plt.show()
print(f'Number of Visit time for 1 Day starting at Upper-right:Central={central_visit}, Side={side_visit}, Corner={corner_visit}')
# Out:
# Number of Visit time for 1 Day starting at Upper-right:Central=63519.0, Side=21185.0, Corner=1696.0

# %%
grid_size = 11
num_trials = 100
runtime = 3600  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (grid_size // 2, grid_size // 2)  # Starting in the center
        for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'1 Hour Average Dirtiness Center ({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 1 Hour {mode.capitalize()} Mode Starting at Center: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')
# Out:
# Average Dirtiness for 1 Hour Random Mode Starting at Center: Central=9.994352436378698, Side=15.69126516526458, Corner=24.626354806445683
# Average Dirtiness for 1 Hour Greedy Mode Starting at Center: Central=2.90969096125516, Side=3.2870609549575125, Corner=3.9808795076663177

# %%
grid_size = 11
num_trials = 100
runtime = 28800  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (grid_size // 2, grid_size // 2)  # Starting in the center
        for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'8 Hour Average Dirtiness Center ({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 8 Hour {mode.capitalize()} Mode Starting at Center: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')
# Out:
# Average Dirtiness for 8 Hour Random Mode Starting at Center: Central=11.618193384142705, Side=17.27534441615493, Corner=26.6864296025291
# Average Dirtiness for 8 Hour Greedy Mode Starting at Center: Central=2.8132129280266023, Side=3.319347592498304, Corner=4.088537489289635

# %%
grid_size = 11
num_trials = 100
runtime = 86400  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (grid_size // 2, grid_size // 2)  # Starting in the center
        for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'1 Day Average Dirtiness Center ({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 1 Day {mode.capitalize()} Mode Starting at Center: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')

# %%
grid_size = 11
num_trials = 100
runtime = 3600  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (0, -1)  # Starting in the upper-right
        for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'1 Hour Average Dirtiness upper-right({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 1 Hour {mode.capitalize()} Mode Starting at upper-right: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')
# Out:
# Random Mode: Central=11.965530457032404, Side=18.075438448198682, Corner=27.563924312627382
# Greedy Mode: Central=2.952854107139788, Side=3.329293167485924, Corner=3.957303394075013

# %%
grid_size = 11
num_trials = 100
runtime = 28800  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (0, -1)  # Starting in the upper-right
         for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'8 Hour Average Dirtiness upper-right ({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 8 Hour {mode.capitalize()} Mode staring at upper-right: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')

# %%
grid_size = 11
num_trials = 100
runtime = 86400  # seconds

dirtiness_values = {
    'random': np.zeros((num_trials, grid_size, grid_size)),
    'greedy': np.zeros((num_trials, grid_size, grid_size))
}

for mode in ['random', 'greedy']:
    for trial in range(num_trials):
        dirtiness = np.zeros((grid_size, grid_size))
        position = (0, -1)  # Starting in the upper-right
        for _ in range(runtime):  
            # Create a list of all possible grid positions
            all_positions = [(i, j) for i in range(grid_size) for j in range(grid_size)]
            # Contaminate 10 random grids each second
            selected_positions = np.random.choice(len(all_positions), size=10, replace=False)
            for pos in selected_positions:
                i, j = all_positions[pos]
                dirtiness[i, j] += np.random.uniform(0, 1)
            
                
            # Movement behavior
            moves = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # right, down, left, up
            if mode == 'random':
                valid_moves = []
                # Check all possible moves and keep only valid ones (those that stay within bounds)
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        valid_moves.append(move)
    
                # Choose a valid random move
                move = valid_moves[np.random.randint(0, len(valid_moves))]
                position = (position[0] + move[0], position[1] + move[1])
            elif mode == 'greedy':
                # Check all possible positions and move to the dirtiest
                best_move = []
                max_dirt = -1
                for move in moves:
                    new_position = (position[0] + move[0], position[1] + move[1])
                    if 0 <= new_position[0] < grid_size and 0 <= new_position[1] < grid_size:
                        if dirtiness[new_position] > max_dirt:
                            max_dirt = dirtiness[new_position]
                            best_move = [new_position]
                        elif dirtiness[new_position] == max_dirt:
                            best_move.append(new_position)
                position = best_move[np.random.randint(0, len(best_move))]
                
            # Clean the current grid
            dirtiness[position] = 0
            
        dirtiness_values[mode][trial] = dirtiness

for mode in ['random', 'greedy']:
    average_dirtiness = np.mean(dirtiness_values[mode], axis=0)
    plt.figure()
    plt.imshow(average_dirtiness, cmap='Blues', interpolation='nearest')
    plt.colorbar(label='Average Dirtiness')
    plt.title(f'1 Day Average Dirtiness upper-right({mode.capitalize()} Mode)')
    plt.show()

    # Calculate the dirtiness of central, side, and corner grids
    central_dirtiness = np.mean(average_dirtiness[1:-1, 1:-1])
    side_dirtiness = (np.mean(average_dirtiness[0, 1:-1]) +
                      np.mean(average_dirtiness[-1, 1:-1]) +
                      np.mean(average_dirtiness[1:-1, 0]) +
                      np.mean(average_dirtiness[1:-1, -1])) / 4
    corner_dirtiness = (average_dirtiness[0, 0] +
                        average_dirtiness[0, -1] +
                        average_dirtiness[-1, 0] +
                        average_dirtiness[-1, -1]) / 4
    print(f'Average Dirtiness for 1 Day {mode.capitalize()} Mode Starting at upper-right: Central={central_dirtiness}, Side={side_dirtiness}, Corner={corner_dirtiness}')
